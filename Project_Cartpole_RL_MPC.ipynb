# %%
import random
import gym
import numpy as np
from collections import deque
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam

from gekko import GEKKO
import math

# Construct MPC
m = GEKKO(remote=True)
m.time = [0,0.02,0.04,0.08,0.16,0.32,0.4] #np.arange(0,0.401,0.05)

# Parameters
masspole = m.Param(0.1)
polemass_length = m.Param(0.05)
total_mass = m.Param(1.1)
gravity = m.Param(9.8)
length = m.Param(0.5)

# Manipulated variable 
u = m.MV(1, lb=0, ub=1, name='u', integer=True)
u.STATUS = 1

# Controlled variable 
ni = ['x','xdot','theta','thetadot']
y = [m.CV(name=ni[i]) for i in range(4)]
x = y[0]
xdot = y[1]
theta = y[2]
thetadot = y[3]
x.STATUS = 1; x.FSTATUS = 1;
xdot.STATUS = 1; xdot.FSTATUS = 1;
theta.STATUS = 1; theta.FSTATUS = 1;
thetadot.STATUS = 1; thetadot.FSTATUS = 1;
m.Minimize(x**2 + theta**2)

# Process model
force = m.Intermediate(20*u-10)
costheta = m.Intermediate(m.cos(theta))
sintheta = m.Intermediate(m.sin(theta))
temp = m.Intermediate((force + polemass_length * thetadot * thetadot * sintheta)/total_mass)
thetaacc = m.Intermediate((gravity * sintheta - costheta * temp)/length * (4.0/3.0 - masspole * costheta * costheta / total_mass))
xacc = m.Intermediate(temp - polemass_length * thetaacc * costheta / total_mass)

m.Equation(x.dt() == xdot)
m.Equation(xdot.dt() == xacc)
m.Equation(theta.dt() == thetadot)
m.Equation(thetadot.dt() == thetaacc)

m.options.IMODE = 6
m.options.solver = 1


# Construct RL agent
class DQNAgent:
    def __init__(self, state_size, action_size):
        self.state_size = state_size
        self.action_size = action_size
        self.memory = deque(maxlen=2000)
        self.gamma = 0.95    # discount rate
        self.epsilon = 1.0  # exploration rate
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.995
        self.learning_rate = 0.001
        self.model = self._build_model()

    def _build_model(self):
        # Neural Net for Deep-Q learning Model
        model = Sequential()
        model.add(Dense(24, input_dim=self.state_size, activation='relu'))
        model.add(Dense(24, activation='relu'))
        model.add(Dense(self.action_size, activation='linear'))
        model.compile(loss='mse',
                      optimizer=Adam(lr=self.learning_rate))
        return model

    def memorize(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state):
#         if np.random.rand() <= self.epsilon:
#             return random.randrange(self.action_size)
        act_values = self.model.predict(state)
        return np.argmax(act_values[0])  # returns action

    def replay(self, batch_size):
        minibatch = random.sample(self.memory, batch_size)
        for state, action, reward, next_state, done in minibatch:
            target = reward
            if not done:
                target = (reward + self.gamma *
                          np.amax(self.model.predict(next_state)[0]))
            target_f = self.model.predict(state)
            target_f[0][action] = target
            self.model.fit(state, target_f, epochs=1, verbose=0)
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

    def load(self, name):
        self.model.load_weights(name)

    def save(self, name):
        self.model.save_weights(name)

EPISODES = 50 # evaluation episodes
if __name__ == "__main__":
    env = gym.make('CartPole-v1')
    state_size = env.observation_space.shape[0]
    action_size = env.action_space.n
    agent = DQNAgent(state_size, action_size)
    agent.load("cartpole-dqn.h5")
    done = False
    batch_size = 32
    score_RL = []; score_MPC = []

    for e in range(EPISODES):
        state_init = env.reset()
        state_init = np.reshape(state_init, [1, state_size])
        
        state = state_init
        # DQNagent
        for time in range(500):
            # env.render()
            action = agent.act(state)
            next_state, reward, done, _ = env.step(action)
            reward = reward if not done else -10
            next_state = np.reshape(next_state, [1, state_size])
#             agent.memorize(state, action, reward, next_state, done)
            state = next_state
            if done:
                print("episode_RL: {}/{}, score: {}, e: {:.2}"
                      .format(e, EPISODES, time, agent.epsilon))
                break                    
        score_RL.append(time)
        
        state = state_init
        # MPC
        for time in range(500):
            # env.render()
            x.MEAS = state[0,0]; xdot.MEAS = state[0,1]; theta.MEAS = state[0,2]; thetadot.MEAS = state[0,3]
            print(m.path)
            m.solve(disp=True)
            action = u.NEWVAL
            print(action)
            next_state, reward, done, _ = env.step(action)
            reward = reward if not done else -10
            next_state = np.reshape(next_state, [1, state_size])
#             agent.memorize(state, action, reward, next_state, done)
            state = next_state
            if done:
                print("episode_MPC: {}/{}, score: {}, e: {:.2}"
                      .format(e, EPISODES, time, agent.epsilon))
                break                    
        score_MPC.append(time)

#             if len(agent.memory) > batch_size:
#                 agent.replay(batch_size)
        # if e % 10 == 0:
        #     agent.save("./save/cartpole-dqn.h5")
# Out:
# Using TensorFlow backend.
# WARNING: Logging before flag parsing goes to stderr.
# W0115 11:25:20.998301  8780 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# episode_RL: 0/50, score: 85, e: 1.0
# C:\Users\rwer\AppData\Local\Temp\tmp1jiz0zxwgk_model0
# apm 147.46.91.150_gk_model0 <br><pre> ----------------------------------------------------------------
#  APMonitor, Version 0.9.2
#  APMonitor Optimization Suite
#  ----------------------------------------------------------------
#
#
#  --------- APM Model Size ------------
#  Each time step contains
#    Objects      :            0
#    Constants    :            0
#    Variables    :           10
#    Intermediates:            6
#    Connections  :            0
#    Equations    :           11
#    Residuals    :            5
#
#  Number of state variables:            342
#  Number of total equations: -          336
#  Number of slack variables: -            0
#  ---------------------------------------
#  Degrees of freedom       :              6
#
#  ----------------------------------------------
#  Dynamic Control with APOPT Solver
#  ----------------------------------------------
# Iter:     1 I:  0 Tm:      0.05 NLPi:   14 Dpth:    0 Lvs:    3 Obj:  5.00E-06 Gap:       NaN
# --Integer Solution:   7.93E+02 Lowest Leaf:   5.00E-06 Gap:   2.00E+00
# Iter:     2 I:  0 Tm:      0.03 NLPi:    9 Dpth:    1 Lvs:    2 Obj:  7.93E+02 Gap:  2.00E+00
# Iter:     3 I:  0 Tm:      0.03 NLPi:    5 Dpth:    1 Lvs:    4 Obj:  5.24E+01 Gap:  2.00E+00
# Iter:     4 I:  0 Tm:      0.03 NLPi:    5 Dpth:    1 Lvs:    6 Obj:  5.24E+01 Gap:  2.00E+00
# --Integer Solution:   7.93E+02 Lowest Leaf:   5.24E+01 Gap:   1.75E+00
# Iter:     5 I:  0 Tm:      0.04 NLPi:    8 Dpth:    2 Lvs:    5 Obj:  8.19E+02 Gap:  1.75E+00
# Iter:     6 I:  0 Tm:      0.03 NLPi:    5 Dpth:    2 Lvs:    7 Obj:  1.08E+02 Gap:  1.75E+00
# Iter:     7 I:  0 Tm:      0.03 NLPi:    5 Dpth:    2 Lvs:    9 Obj:  1.09E+02 Gap:  1.75E+00
# --Integer Solution:   7.78E+02 Lowest Leaf:   5.24E+01 Gap:   1.75E+00
# Iter:     8 I:  0 Tm:      0.03 NLPi:   10 Dpth:    2 Lvs:    8 Obj:  7.78E+02 Gap:  1.75E+00
# Iter:     9 I:  0 Tm:      0.02 NLPi:    5 Dpth:    2 Lvs:   10 Obj:  1.09E+02 Gap:  1.75E+00
# Iter:    10 I:  0 Tm:      0.02 NLPi:    5 Dpth:    2 Lvs:   12 Obj:  1.08E+02 Gap:  1.75E+00
# --Integer Solution:   2.80E+02 Lowest Leaf:   1.08E+02 Gap:   8.85E-01
# Iter:    11 I:  0 Tm:      0.02 NLPi:    5 Dpth:    3 Lvs:   11 Obj:  2.80E+02 Gap:  8.85E-01
# Iter:    12 I:  0 Tm:      0.03 NLPi:    5 Dpth:    3 Lvs:   13 Obj:  1.21E+02 Gap:  8.85E-01
# Iter:    13 I:  0 Tm:      0.02 NLPi:    5 Dpth:    3 Lvs:   15 Obj:  1.20E+02 Gap:  8.85E-01
# --Integer Solution:   2.20E+02 Lowest Leaf:   1.08E+02 Gap:   6.82E-01
# Iter:    14 I:  0 Tm:      0.02 NLPi:    6 Dpth:    3 Lvs:   14 Obj:  2.20E+02 Gap:  6.82E-01
# Iter:    15 I:  0 Tm:      0.02 NLPi:    5 Dpth:    3 Lvs:   16 Obj:  1.20E+02 Gap:  6.82E-01
# Iter:    16 I:  0 Tm:      0.03 NLPi:    5 Dpth:    3 Lvs:   18 Obj:  1.21E+02 Gap:  6.82E-01
# Iter:    17 I:  0 Tm:      0.02 NLPi:    5 Dpth:    3 Lvs:   18 Obj:  1.62E+02 Gap:  6.82E-01
# Iter:    18 I:  0 Tm:      0.03 NLPi:    5 Dpth:    3 Lvs:   20 Obj:  1.21E+02 Gap:  6.82E-01
# Iter:    19 I:  0 Tm:      0.03 NLPi:    5 Dpth:    3 Lvs:   22 Obj:  1.19E+02 Gap:  6.82E-01
# --Integer Solution:   2.20E+02 Lowest Leaf:   1.09E+02 Gap:   6.79E-01
# Iter:    20 I:  0 Tm:      0.02 NLPi:    5 Dpth:    3 Lvs:   21 Obj:  2.20E+02 Gap:  6.79E-01
# Iter:    21 I:  0 Tm:      0.02 NLPi:    5 Dpth:    3 Lvs:   23 Obj:  1.19E+02 Gap:  6.79E-01
# Iter:    22 I:  0 Tm:      0.03 NLPi:    5 Dpth:    3 Lvs:   25 Obj:  1.21E+02 Gap:  6.79E-01
# --Integer Solution:   2.20E+02 Lowest Leaf:   1.19E+02 Gap:   5.95E-01
# Iter:    23 I:  0 Tm:      0.02 NLPi:    6 Dpth:    4 Lvs:   24 Obj:  3.23E+02 Gap:  5.95E-01
# Iter:    24 I:  0 Tm:      0.03 NLPi:    7 Dpth:    4 Lvs:   23 Obj:  4.67E+02 Gap:  5.95E-01
# Iter:    25 I:  0 Tm:      0.03 NLPi:    8 Dpth:    4 Lvs:   25 Obj:  1.38E+02 Gap:  5.95E-01
# Iter:    26 I:  0 Tm:      0.02 NLPi:    4 Dpth:    4 Lvs:   26 Obj:  1.38E+02 Gap:  5.95E-01
# Iter:    27 I:  0 Tm:      0.02 NLPi:    5 Dpth:    4 Lvs:   28 Obj:  1.38E+02 Gap:  5.95E-01
# Iter:    28 I:  0 Tm:      0.03 NLPi:    7 Dpth:    4 Lvs:   27 Obj:  4.67E+02 Gap:  5.95E-01
# --Integer Solution:   2.20E+02 Lowest Leaf:   1.20E+02 Gap:   5.93E-01
# Iter:    29 I:  0 Tm:      0.02 NLPi:    7 Dpth:    4 Lvs:   26 Obj:  3.94E+02 Gap:  5.93E-01
# --Integer Solution:   2.20E+02 Lowest Leaf:   1.20E+02 Gap:   5.93E-01
# Iter:    30 I:  0 Tm:      0.02 NLPi:    6 Dpth:    4 Lvs:   25 Obj:  4.05E+02 Gap:  5.93E-01
# Iter:    31 I:  0 Tm:      0.02 NLPi:    6 Dpth:    4 Lvs:   27 Obj:  1.85E+02 Gap:  5.93E-01
# Iter:    32 I:  0 Tm:      0.03 NLPi:    8 Dpth:    4 Lvs:   28 Obj:  1.35E+02 Gap:  5.93E-01
# Iter:    33 I:  0 Tm:      0.02 NLPi:    6 Dpth:    4 Lvs:   30 Obj:  1.85E+02 Gap:  5.93E-01
# --Integer Solution:   2.20E+02 Lowest Leaf:   1.21E+02 Gap:   5.80E-01
# Iter:    34 I:  0 Tm:      0.02 NLPi:    6 Dpth:    4 Lvs:   29 Obj:  4.05E+02 Gap:  5.80E-01
# Iter:    35 I:  0 Tm:      0.02 NLPi:    6 Dpth:    4 Lvs:   31 Obj:  1.36E+02 Gap:  5.80E-01
# Iter:    36 I:  0 Tm:      0.02 NLPi:    5 Dpth:    4 Lvs:   33 Obj:  1.84E+02 Gap:  5.80E-01
# --Integer Solution:   2.20E+02 Lowest Leaf:   1.21E+02 Gap:   5.80E-01
# Iter:    37 I:  0 Tm:      0.02 NLPi:    6 Dpth:    4 Lvs:   32 Obj:  4.80E+02 Gap:  5.80E-01
# --Integer Solution:   2.20E+02 Lowest Leaf:   1.21E+02 Gap:   5.80E-01
# Iter:    38 I:  0 Tm:      0.02 NLPi:    7 Dpth:    4 Lvs:   31 Obj:  4.00E+02 Gap:  5.80E-01
# --Integer Solution:   2.20E+02 Lowest Leaf:   1.21E+02 Gap:   5.80E-01
# Iter:    39 I:  0 Tm:      0.02 NLPi:    6 Dpth:    4 Lvs:   30 Obj:  4.80E+02 Gap:  5.80E-01
# Iter:    40 I:  0 Tm:      0.02 NLPi:    4 Dpth:    4 Lvs:   32 Obj:  1.84E+02 Gap:  5.80E-01
# Iter:    41 I:  0 Tm:      0.02 NLPi:    4 Dpth:    4 Lvs:   33 Obj:  1.41E+02 Gap:  5.80E-01
# Iter:    42 I:  0 Tm:      0.02 NLPi:    5 Dpth:    4 Lvs:   35 Obj:  1.38E+02 Gap:  5.80E-01
# --Integer Solution:   2.20E+02 Lowest Leaf:   1.21E+02 Gap:   5.79E-01
# Iter:    43 I:  0 Tm:      0.04 NLPi:   10 Dpth:    4 Lvs:   34 Obj:  5.05E+02 Gap:  5.79E-01
# --Integer Solution:   2.20E+02 Lowest Leaf:   1.21E+02 Gap:   5.79E-01
# Iter:    44 I:  0 Tm:      0.02 NLPi:    6 Dpth:    4 Lvs:   33 Obj:  3.33E+02 Gap:  5.79E-01
# --Integer Solution:   2.20E+02 Lowest Leaf:   1.21E+02 Gap:   5.79E-01
# Iter:    45 I:  0 Tm:      0.04 NLPi:   10 Dpth:    4 Lvs:   32 Obj:  5.05E+02 Gap:  5.79E-01
# Iter:    46 I:  0 Tm:      0.02 NLPi:    6 Dpth:    4 Lvs:   34 Obj:  1.38E+02 Gap:  5.79E-01
# Iter:    47 I:  0 Tm:      0.02 NLPi:    6 Dpth:    5 Lvs:   35 Obj:  1.62E+02 Gap:  5.79E-01
# Iter:    48 I:  0 Tm:      0.02 NLPi:    8 Dpth:    5 Lvs:   34 Obj:  4.63E+02 Gap:  5.79E-01
# --Integer Solution:   2.20E+02 Lowest Leaf:   1.36E+02 Gap:   4.74E-01
# Iter:    49 I:  0 Tm:      0.02 NLPi:    6 Dpth:    5 Lvs:   33 Obj:  4.10E+02 Gap:  4.74E-01
# --Integer Solution:   2.20E+02 Lowest Leaf:   1.36E+02 Gap:   4.74E-01
# Iter:    50 I:  0 Tm:      0.02 NLPi:    8 Dpth:    5 Lvs:   32 Obj:  3.33E+02 Gap:  4.74E-01
# Iter:    51 I:  0 Tm:      0.03 NLPi:    9 Dpth:    5 Lvs:   31 Obj:  4.02E+02 Gap:  4.74E-01
# Iter:    52 I:  0 Tm:      0.02 NLPi:    5 Dpth:    5 Lvs:   31 Obj:  1.22E+02 Gap:  4.74E-01
# --Integer Solution:   2.20E+02 Lowest Leaf:   1.38E+02 Gap:   4.63E-01
# Iter:    53 I:  0 Tm:      0.03 NLPi:    8 Dpth:    6 Lvs:   30 Obj:  5.05E+02 Gap:  4.63E-01
# Iter:    54 I:  0 Tm:      0.02 NLPi:    5 Dpth:    5 Lvs:   29 Obj:  1.41E+02 Gap:  4.63E-01
# --Integer Solution:   1.64E+02 Lowest Leaf:   1.38E+02 Gap:   1.73E-01
# Iter:    55 I:  0 Tm:      0.02 NLPi:    4 Dpth:    5 Lvs:   28 Obj:  1.64E+02 Gap:  1.73E-01
# Iter:    56 I:  0 Tm:      0.02 NLPi:    4 Dpth:    5 Lvs:   30 Obj:  1.62E+02 Gap:  1.73E-01
# --Integer Solution:   1.64E+02 Lowest Leaf:   1.38E+02 Gap:   1.73E-01
# Iter:    57 I:  0 Tm:      0.02 NLPi:    4 Dpth:    5 Lvs:   29 Obj:  1.64E+02 Gap:  1.73E-01
# Iter:    58 I:  0 Tm:      0.02 NLPi:    5 Dpth:    5 Lvs:   30 Obj:  1.41E+02 Gap:  1.73E-01
# Iter:    59 I:  0 Tm:      0.02 NLPi:    4 Dpth:    5 Lvs:   32 Obj:  1.59E+02 Gap:  1.73E-01
# Iter:    60 I:  0 Tm:      0.03 NLPi:    7 Dpth:    5 Lvs:   33 Obj:  1.57E+02 Gap:  1.73E-01
# --Integer Solution:   1.64E+02 Lowest Leaf:   1.38E+02 Gap:   1.73E-01
# Iter:    61 I:  0 Tm:      0.02 NLPi:    6 Dpth:    5 Lvs:   32 Obj:  3.23E+02 Gap:  1.73E-01
# --Integer Solution:   1.64E+02 Lowest Leaf:   1.38E+02 Gap:   1.73E-01
# Iter:    62 I:  0 Tm:      0.02 NLPi:    7 Dpth:    5 Lvs:   31 Obj:  4.65E+02 Gap:  1.73E-01
# --Integer Solution:   1.64E+02 Lowest Leaf:   1.38E+02 Gap:   1.73E-01
# Iter:    63 I:  0 Tm:      0.02 NLPi:    6 Dpth:    5 Lvs:   30 Obj:  3.23E+02 Gap:  1.73E-01
# Iter:    64 I:  0 Tm:      0.02 NLPi:    4 Dpth:    5 Lvs:   31 Obj:  1.57E+02 Gap:  1.73E-01
# Iter:    65 I:  0 Tm:      0.01 NLPi:    4 Dpth:    5 Lvs:   32 Obj:  1.62E+02 Gap:  1.73E-01
# --Integer Solution:   1.64E+02 Lowest Leaf:   1.41E+02 Gap:   1.47E-01
# Iter:    66 I:  0 Tm:      0.02 NLPi:    6 Dpth:    5 Lvs:   31 Obj:  4.65E+02 Gap:  1.47E-01
# --Integer Solution:   1.64E+02 Lowest Leaf:   1.41E+02 Gap:   1.47E-01
# Iter:    67 I:  0 Tm:      0.02 NLPi:    6 Dpth:    5 Lvs:   30 Obj:  3.33E+02 Gap:  1.47E-01
# --Integer Solution:   1.64E+02 Lowest Leaf:   1.41E+02 Gap:   1.47E-01
# Iter:    68 I:  0 Tm:      0.02 NLPi:    6 Dpth:    5 Lvs:   29 Obj:  4.10E+02 Gap:  1.47E-01
# --Integer Solution:   1.64E+02 Lowest Leaf:   1.41E+02 Gap:   1.47E-01
# Iter:    69 I:  0 Tm:      0.02 NLPi:    6 Dpth:    6 Lvs:   28 Obj:  4.10E+02 Gap:  1.47E-01
# --Integer Solution:   1.64E+02 Lowest Leaf:   1.57E+02 Gap:   4.13E-02
# Iter:    70 I:  0 Tm:      0.02 NLPi:    6 Dpth:    6 Lvs:   27 Obj:  3.33E+02 Gap:  4.13E-02
# --Integer Solution:   1.64E+02 Lowest Leaf:   1.57E+02 Gap:   4.13E-02
# Iter:    71 I:  0 Tm:      0.02 NLPi:    5 Dpth:    6 Lvs:   26 Obj:  2.20E+02 Gap:  4.13E-02
# --Integer Solution:   1.64E+02 Lowest Leaf:   1.57E+02 Gap:   4.13E-02
# Iter:    72 I:  0 Tm:      0.02 NLPi:    6 Dpth:    6 Lvs:   25 Obj:  4.65E+02 Gap:  4.13E-02
# --Integer Solution:   1.64E+02 Lowest Leaf:   1.57E+02 Gap:   4.13E-02
# Iter:    73 I:  0 Tm:      0.02 NLPi:    6 Dpth:    6 Lvs:   24 Obj:  4.65E+02 Gap:  4.13E-02
# --Integer Solution:   1.64E+02 Lowest Leaf:   1.59E+02 Gap:   2.56E-02
# Iter:    74 I:  0 Tm:      0.02 NLPi:    5 Dpth:    6 Lvs:   23 Obj:  2.20E+02 Gap:  2.56E-02
# Iter:    75 I:  0 Tm:      0.02 NLPi:    4 Dpth:    6 Lvs:   24 Obj:  1.38E+02 Gap:  2.56E-02
# Iter:    76 I:  0 Tm:      0.03 NLPi:    7 Dpth:    7 Lvs:   23 Obj:  1.57E+02 Gap:  2.56E-02
# --Integer Solution:   1.64E+02 Lowest Leaf:   1.59E+02 Gap:   2.56E-02
# Iter:    77 I:  0 Tm:      0.02 NLPi:    6 Dpth:    7 Lvs:   22 Obj:  3.23E+02 Gap:  2.56E-02
# Iter:    78 I:  0 Tm:      0.02 NLPi:    8 Dpth:    6 Lvs:   21 Obj:  4.63E+02 Gap:  2.56E-02
# --Integer Solution:   1.64E+02 Lowest Leaf:   1.62E+02 Gap:   1.15E-02
# Iter:    79 I:  0 Tm:      0.02 NLPi:    6 Dpth:    6 Lvs:   20 Obj:  4.80E+02 Gap:  1.15E-02
# Iter:    80 I:  0 Tm:      0.02 NLPi:    4 Dpth:    6 Lvs:   20 Obj:  1.61E+02 Gap:  1.15E-02
# --Integer Solution:   1.64E+02 Lowest Leaf:   1.62E+02 Gap:   1.15E-02
# Iter:    81 I:  0 Tm:      0.02 NLPi:    6 Dpth:    7 Lvs:   19 Obj:  3.33E+02 Gap:  1.15E-02
# Iter:    82 I:  0 Tm:      0.02 NLPi:    4 Dpth:    6 Lvs:   19 Obj:  1.62E+02 Gap:  1.15E-02
# --Integer Solution:   1.64E+02 Lowest Leaf:   1.62E+02 Gap:   1.15E-02
# Iter:    83 I:  0 Tm:      0.02 NLPi:    5 Dpth:    6 Lvs:   18 Obj:  2.80E+02 Gap:  1.15E-02
# --Integer Solution:   1.64E+02 Lowest Leaf:   1.62E+02 Gap:   1.15E-02
# Iter:    84 I:  0 Tm:      0.01 NLPi:    4 Dpth:    6 Lvs:   17 Obj:  1.64E+02 Gap:  1.15E-02
# --Integer Solution:   1.64E+02 Lowest Leaf:   1.62E+02 Gap:   1.14E-02
# Iter:    85 I:  0 Tm:      0.02 NLPi:    5 Dpth:    6 Lvs:   16 Obj:  2.80E+02 Gap:  1.14E-02
# Iter:    86 I:  0 Tm:      0.02 NLPi:    4 Dpth:    4 Lvs:   17 Obj:  1.63E+02 Gap:  1.14E-02
# --Integer Solution:   1.64E+02 Lowest Leaf:   1.62E+02 Gap:   9.90E-03
# Iter:    87 I:  0 Tm:      0.02 NLPi:    6 Dpth:    7 Lvs:   17 Obj:  3.23E+02 Gap:  9.90E-03
#  Successful solution
#
#  ---------------------------------------------------
#  Solver         :  APOPT (v1.0)
#  Solution time  :    1.99189999999908      sec
#  Objective      :    163.597079204263
#  Successful solution
#  ---------------------------------------------------
#
# 1.0
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-1-0e53913a2017> in <module>
#     146             action = u.NEWVAL
#     147             print(action)
# --> 148             next_state, reward, done, _ = env.step(action)
#     149             reward = reward if not done else -10
#     150             next_state = np.reshape(next_state, [1, state_size])
#
# C:\ProgramData\Anaconda3\lib\site-packages\gym\wrappers\time_limit.py in step(self, action)
#      14     def step(self, action):
#      15         assert self._elapsed_steps is not None, "Cannot call env.step() before calling reset()"
# ---> 16         observation, reward, done, info = self.env.step(action)
#      17         self._elapsed_steps += 1
#      18         if self._elapsed_steps >= self._max_episode_steps:
#
# C:\ProgramData\Anaconda3\lib\site-packages\gym\envs\classic_control\cartpole.py in step(self, action)
#      90
#      91     def step(self, action):
# ---> 92         assert self.action_space.contains(action), "%r (%s) invalid"%(action, type(action))
#      93         state = self.state
#      94         x, x_dot, theta, theta_dot = state
#
# AssertionError: 1.0 (<class 'float'>) invalid

# %%
print(np.mean(score_RL))

# %%
print(action_size)

# %%
state[0,1]
